# %%
student = {
    "name": "Ram",
    "age": 20,
    "faculty": "BCE"
}

# %%
student["name"]
# Out:
# 'ram'

# %%
student.get("name")
# Out:
# 'ram'

# %%
print(student)
# Out:
# {'name': 'ram', 'age': 20, 'faculty': 'BCE'}

# %%
del student["age"]

# %%
print(student)
# Out:
# {'name': 'Ram', 'age': 20, 'faculty': 'BCE'}

# %%
new_s=student.copy()

# %%
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(s)
#
# NameError: name 's' is not defined
